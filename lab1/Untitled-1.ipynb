# %%
from easyAI.AI import TranspositionTable
from easyAI import TwoPlayerGame, Human_Player, AI_Player, Negamax, solve_with_iterative_deepening
import random

# %%
WORD = "SHUFFLE"

# %%
def shuffle(string):
  """
  Shuffle the letters of a string

  :param string: the string to shuffle
  :return: the shuffled string
  """
  l = list(string)
  random.shuffle(l)
  return ''.join(l)

def swap(string, i1, i2):
  """
  Swap two letters in a string

  :param string: the string to swap
  :param i1: the index of the first letter
  :param i2: the index of the second letter
  :return: the string with the two letters swapped
  """
  strList = list(string)
  buff = strList[i1]
  strList[i1] = strList[i2]
  strList[i2] = buff
  return ''.join(strList) 

def move_letter(string, pos, dir):
  """
  Move a letter in a string

  :param string: the string to move the letter in
  :param pos: the position of the letter to move
  :param dir: the direction to move the letter in
  :return: the string with the letter moved
  """
  targetPos = pos + (1 if dir == 'r' else -1)
  if(pos<0 or pos>=len(string)):
    return string

  if(targetPos<0):
    targetPos = len(string)-1

  if(targetPos>=len(string)):
    targetPos = 0

  new_string = swap(string, pos, targetPos)
  return new_string

def matching_chars_count(string1, string2):
  """
  Count the number of matching characters between two strings

  :param string1: the first string
  :param string2: the second string
  :return: the number of matching characters
  """
  count = 0
  for i in range(0, len(string1)):
    if(string1[i] == string2[i]):
      count += 1
  return count

# %%
class Reorganize(TwoPlayerGame):
    """
    In turn, the players reorganize the letters of a word.
    The player who reorganizes the word wins.

    The word is shuffled at the beginning of the game.
    The players can move a letter to the left or to the right.
    The players can move two letters at the same time.

    The game stops when the word is reorganized.
    """

    def __init__(self, players=None):
        self.players = players
        self.word = shuffle(WORD)
        self.current_player = 1  # player 1 starts

    def possible_moves(self):
        """
        Return the possible moves for the current player

        :return: the possible moves
        """
        moves = ["%d%s" % (i, dir) for i in range(len(self.word)) for dir in ['l', 'r']]
        double_moves = ['%s %s' % (m1, m2) for m1 in moves for m2 in moves]
        moves.extend(double_moves)
        return moves

    def make_move(self, move):
        """
        Make a move for the current player

        :param move: the move to make
        """
        moves = move.split(' ')
        for m in moves:
            i, dir = m[:-1], m[-1:]
            self.word = move_letter(self.word, int(i), dir)

    def is_over(self):
        """
        Check if the game is over
        
        :return: True if the game is over, False otherwise
        """
        return self.word == WORD

    def show(self):
        """
        Show the current state of the game
        """
        for i in range(len(self.word)):
            print(i, end='')
        print("\n%s" % self.word)
        print(WORD)
        print('wrong letters: %d' % (len(WORD) - matching_chars_count(self.word, WORD)))

    def scoring(self): return -(len(WORD)**2 if self.is_over() else matching_chars_count(self.word, WORD))

# %%
ai = Negamax(3)
# game = Reorganize([Human_Player(), AI_Player(ai)])
game = Reorganize([AI_Player(ai), AI_Player(ai)])
history = game.play()
print('%d wins!' % game.current_player)
# Out:
# 0123456
# LFHFESU
# SHUFFLE
# wrong letters: 6
#
# Move #1: player 1 plays 0l :
# 0123456
# UFHFESL
# SHUFFLE
# wrong letters: 6
#
# Move #2: player 2 plays 0r 1r :
# 0123456
# FHUFESL
# SHUFFLE
# wrong letters: 4
#
# Move #3: player 1 plays 4r 5r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #4: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #5: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #6: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #7: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #8: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #9: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #10: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #11: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #12: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #13: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #14: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #15: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #16: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #17: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #18: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #19: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #20: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #21: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #22: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
#
# Move #23: player 1 plays 3r :
# 0123456
# FHUFSLE
# SHUFFLE
# wrong letters: 2
#
# Move #24: player 2 plays 3r :
# 0123456
# FHUSFLE
# SHUFFLE
# wrong letters: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/schibsted/dev/pjatk/nai/Untitled-1.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/schibsted/dev/pjatk/nai/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # game = Reorganize([Human_Player(), AI_Player(ai)])
#       <a href='vscode-notebook-cell:/Users/schibsted/dev/pjatk/nai/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> game = Reorganize([AI_Player(ai), AI_Player(ai)])
# ----> <a href='vscode-notebook-cell:/Users/schibsted/dev/pjatk/nai/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> history = game.play()
#       <a href='vscode-notebook-cell:/Users/schibsted/dev/pjatk/nai/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> print('%d wins!' % game.current_player)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/TwoPlayerGame.py:110, in TwoPlayerGame.play(self, nmoves, verbose)
#     107 if self.is_over():
#     108     break
# --> 110 move = self.player.ask_move(self)
#     111 history.append((deepcopy(self), move))
#     112 self.make_move(move)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/Player.py:63, in AI_Player.ask_move(self, game)
#      62 def ask_move(self, game):
# ---> 63     return self.AI_algo(game)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/AI/Negamax.py:178, in Negamax.__call__(self, game)
#     170 """
#     171 Returns the AI's best move given the current state of the game.
#     172 """
#     174 scoring = (
#     175     self.scoring if self.scoring else (lambda g: g.scoring())
#     176 )  # horrible hack
# --> 178 self.alpha = negamax(
#     179     game,
#     180     self.depth,
#     181     self.depth,
#     182     scoring,
#     183     -self.win_score,
#     184     +self.win_score,
#     185     self.tt,
#     186 )
#     187 return game.ai_move
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/AI/Negamax.py:79, in negamax(game, depth, origDepth, scoring, alpha, beta, tt)
#      76 game.make_move(move)
#      77 game.switch_player()
# ---> 79 move_alpha = -negamax(game, depth - 1, origDepth, scoring, -beta, -alpha, tt)
#      81 if unmake_move:
#      82     game.switch_player()
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/AI/Negamax.py:79, in negamax(game, depth, origDepth, scoring, alpha, beta, tt)
#      76 game.make_move(move)
#      77 game.switch_player()
# ---> 79 move_alpha = -negamax(game, depth - 1, origDepth, scoring, -beta, -alpha, tt)
#      81 if unmake_move:
#      82     game.switch_player()
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/AI/Negamax.py:74, in negamax(game, depth, origDepth, scoring, alpha, beta, tt)
#      71 for move in possible_moves:
#      73     if not unmake_move:
# ---> 74         game = state.copy()  # re-initialize move
#      76     game.make_move(move)
#      77     game.switch_player()
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/easyAI/TwoPlayerGame.py:143, in TwoPlayerGame.copy(self)
#     142 def copy(self):
# --> 143     return deepcopy(self)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/copy.py:177, in deepcopy(x, memo, _nil)
#     175 if y is not x:
#     176     memo[d] = y
# --> 177     _keep_alive(x, memo) # Make sure x lives at least as long as d
#     178 return y
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/copy.py:253, in _keep_alive(x, memo)
#     243 """Keeps a reference to the object x in the memo.
#     244
#     245 Because we remember objects by their id, we have
#    (...)
#     250 the memo itself...
#     251 """
#     252 try:
# --> 253     memo[id(memo)].append(x)
#     254 except KeyError:
#     255     # aha, this is the first one :-)
#     256     memo[id(memo)]=[x]
#
# KeyboardInterrupt:
